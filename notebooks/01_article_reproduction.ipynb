# %% [markdown]
# # Article reproduction (MAWPS agentic scaffold)
#
# This notebook mirrors **REPRODUCTION.md**: validate data, evaluate the checked-in baseline predictions, and (optionally) rerun the full solver.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "pyproject.toml").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from utils.io import load_json, repo_root
from scaffold.evaluator import evaluate_predictions

root = repo_root(ROOT)
gold = load_json(root / "data" / "raw" / "mawps_test.json")
preds = load_json(root / "results" / "metrics" / "article_baseline_predictions.json")
correct, total, parse_fail, acc = evaluate_predictions(gold, preds)
print("correct", correct, "total", total, "parse_fail", parse_fail, "accuracy", acc)

# %% [markdown]
# ## Optional: LangGraph single-problem run
#
# After `pip install -r requirements.txt` and downloading weights, you can run:
#
# ```python
# from pathlib import Path
# from scaffold.solver import AgenticSolver
# from graphs.reasoning_graph import build_reasoning_graph
#
# solver = AgenticSolver(project_root=Path("..").resolve(), use_openai=False)
# solver.load()
# app = build_reasoning_graph(solver)
# state = {"problem": gold[0]["problem"]}
# print(app.invoke(state))
# ```
